# %%
import gdown

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\offic\\End-To-End-Waste-Detection-Using-YOLO'

# %%
url = "https://drive.google.com/file/d/1EnWcitv_N1RTLiuF5k28gIQ5NjiIjbvQ/view?usp=drive_link"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1EnWcitv_N1RTLiuF5k28gIQ5NjiIjbvQ'

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix+file_id, "data/waste_data.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1EnWcitv_N1RTLiuF5k28gIQ5NjiIjbvQ
# To: c:\Users\offic\End-To-End-Waste-Detection-Using-YOLO\data\waste_data.zip
# 100%|██████████| 416k/416k [00:00<00:00, 856kB/s]
# 'data/waste_data.zip'

# %%
#clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...

# %%
# install dependencies as necessary

import torch

# clear_output()
print(
    'Setup complete. Using torch %s %s' %
    (
        torch.__version__,
        torch.cuda.get_device_properties(0)
        if torch.cuda.is_available()
        else 'CPU'
    )
)
# Out:
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# Setup complete. Using torch 2.8.0+cpu CPU
